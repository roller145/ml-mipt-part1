# %% [markdown]
# # CIFAR Conv Net
#
# И так, в этом ноутбуке Вы сделаете превую в своей жизни сверточную сеть! На сложном датасете. Cкачайте его кстати,

# %%
#!mkdir cifar10
#!curl -o cifar-10-python.tar.gz https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#!tar -xvzf cifar-10-python.tar.gz -C cifar10

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from cifar import load_CIFAR10
plt.rcParams['figure.figsize'] = (10.0, 8.0) 

cifar10_dir = './cifar10/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
X_val = X_test
y_val = y_test

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8').transpose(1, 2, 0))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
import lasagne
from theano import tensor as T
from lasagne.nonlinearities import *
from lasagne import init
from lasagne.layers import batch_norm
input_X = T.tensor4("X", dtype='float32')
target_y = T.vector("target Y integer",dtype='int32')
# Out:
# Using cuDNN version 5005 on context None
# Preallocating 1603/2004 Mb (0.800000) on cuda0
# Mapped name None to device cuda0: GeForce GT 740M (0000:01:00.0)

# %%
#1
net = batch_norm(lasagne.layers.InputLayer(shape=(None, 3, 32, 32), input_var=input_X))

#2
net = batch_norm(lasagne.layers.Conv2DLayer(net, 16, 3, pad=1, nonlinearity=lasagne.nonlinearities.leaky_rectify))
net = lasagne.layers.DropoutLayer(net, 0.5)
#3
net = lasagne.layers.MaxPool2DLayer(net, pool_size=(2, 2), stride=2)

#2
net = batch_norm(lasagne.layers.Conv2DLayer(net, 32, 3, pad=1, nonlinearity=lasagne.nonlinearities.leaky_rectify))
net = lasagne.layers.DropoutLayer(net, 0.5)
#3
net = lasagne.layers.MaxPool2DLayer(net, pool_size=(2, 2), stride=2)
#4
net = batch_norm(lasagne.layers.Conv2DLayer(net, 64, 3, pad=1, nonlinearity=lasagne.nonlinearities.leaky_rectify))
#5
net = lasagne.layers.DropoutLayer(net, 0.5)
net = lasagne.layers.MaxPool2DLayer(net, pool_size=(2, 2), stride=2)
#6
net = batch_norm(lasagne.layers.Conv2DLayer(net, 128, 3, pad=1, nonlinearity=lasagne.nonlinearities.leaky_rectify))
#7
net = lasagne.layers.DenseLayer(net,num_units = 100, nonlinearity=leaky_rectify)

net = lasagne.layers.DropoutLayer(net, 0.5)

net = lasagne.layers.DenseLayer(net,num_units = 10, nonlinearity=softmax)

# %%
y_predicted = lasagne.layers.get_output(net)
all_weights = lasagne.layers.get_all_params(net, trainable=True)
print all_weights
# Out:
# [beta, gamma, W, beta, gamma, W, beta, gamma, W, beta, gamma, W, beta, gamma, W, b, W, b]

# %%
loss = lasagne.objectives.categorical_crossentropy(y_predicted, target_y).mean()
accuracy = lasagne.objectives.categorical_accuracy(y_predicted, target_y).mean()

# %%
updates = lasagne.updates.adam(loss, all_weights, learning_rate=0.01)
#updates = lasagne.updates.adadelta(loss, all_weights, learning_rate=0.01)
train_fun = theano.function([input_X,target_y],[loss, accuracy], updates=updates, allow_input_downcast=True)
accuracy_fun = theano.function([input_X,target_y],accuracy, allow_input_downcast=True)

# %% [markdown]
# ### Вот и всё, пошли её учить

# %%
def iterate_minibatches(inputs, targets, batchsize, shuffle=False):
    assert len(inputs) == len(targets)
    if shuffle:
        indices = np.arange(len(inputs))
        np.random.shuffle(indices)
    for start_idx in range(0, len(inputs) - batchsize + 1, batchsize):
        if shuffle:
            excerpt = indices[start_idx:start_idx + batchsize]
        else:
            excerpt = slice(start_idx, start_idx + batchsize)
        yield inputs[excerpt], targets[excerpt]

# %% [markdown]
# # Процесс обучения

# %%
import time

num_epochs = 200 #количество проходов по данным

batch_size = 128 #размер мини-батча

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    train_err = 0
    train_acc = 0
    train_batches = 0
    start_time = time.time()
    for batch in iterate_minibatches(X_train, y_train, batch_size):
        inputs, targets = batch
        train_err_batch, train_acc_batch = train_fun(inputs, targets)
        # print("F",train_err_batch, train_acc_batch)
        train_err += train_err_batch
        train_acc += train_acc_batch
        train_batches += 1

    # And a full pass over the validation data:
    val_acc = 0
    val_batches = 0
    for batch in iterate_minibatches(X_val, y_val, batch_size):
        inputs, targets = batch
        val_acc += accuracy_fun(inputs, targets)
        val_batches += 1

    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration):\t\t{:.6f}".format(train_err / train_batches))
    print("  train accuracy:\t\t{:.2f} %".format(train_acc / train_batches * 100))
    print("  validation accuracy:\t\t{:.2f} %".format(val_acc / val_batches * 100))
# Out:
# Epoch 1 of 200 took 54.398s
#   training loss (in-iteration):		1.979749
#   train accuracy:		27.18 %
#   validation accuracy:		35.93 %
# Epoch 2 of 200 took 56.760s
#   training loss (in-iteration):		1.584074
#   train accuracy:		40.88 %
#   validation accuracy:		44.98 %
# Epoch 3 of 200 took 58.505s
#   training loss (in-iteration):		1.418416
#   train accuracy:		48.51 %
#   validation accuracy:		51.24 %
# Epoch 4 of 200 took 57.761s
#   training loss (in-iteration):		1.309806
#   train accuracy:		53.15 %
#   validation accuracy:		54.91 %
# Epoch 5 of 200 took 54.956s
#   training loss (in-iteration):		1.237891
#   train accuracy:		56.34 %
#   validation accuracy:		57.75 %
# Epoch 6 of 200 took 54.928s
#   training loss (in-iteration):		1.173160
#   train accuracy:		58.94 %
#   validation accuracy:		60.08 %
# Epoch 7 of 200 took 54.970s
#   training loss (in-iteration):		1.127596
#   train accuracy:		60.97 %
#   validation accuracy:		60.84 %
# Epoch 8 of 200 took 54.923s
#   training loss (in-iteration):		1.085781
#   train accuracy:		62.36 %
#   validation accuracy:		62.12 %
# Epoch 9 of 200 took 54.978s
#   training loss (in-iteration):		1.050097
#   train accuracy:		63.45 %
#   validation accuracy:		62.61 %
# Epoch 10 of 200 took 54.931s
#   training loss (in-iteration):		1.010966
#   train accuracy:		65.17 %
#   validation accuracy:		64.28 %
# Epoch 11 of 200 took 54.995s
#   training loss (in-iteration):		0.994971
#   train accuracy:		65.63 %
#   validation accuracy:		64.60 %
# Epoch 12 of 200 took 54.937s
#   training loss (in-iteration):		0.971980
#   train accuracy:		66.50 %
#   validation accuracy:		65.23 %
# Epoch 13 of 200 took 54.986s
#   training loss (in-iteration):		0.954113
#   train accuracy:		67.12 %
#   validation accuracy:		65.23 %
# Epoch 14 of 200 took 54.924s
#   training loss (in-iteration):		0.931785
#   train accuracy:		67.86 %
#   validation accuracy:		65.35 %
# Epoch 15 of 200 took 54.962s
#   training loss (in-iteration):		0.924624
#   train accuracy:		68.03 %
#   validation accuracy:		66.84 %
# Epoch 16 of 200 took 54.929s
#   training loss (in-iteration):		0.905524
#   train accuracy:		68.71 %
#   validation accuracy:		66.58 %
# Epoch 17 of 200 took 54.995s
#   training loss (in-iteration):		0.898476
#   train accuracy:		68.89 %
#   validation accuracy:		67.07 %
# Epoch 18 of 200 took 54.937s
#   training loss (in-iteration):		0.884804
#   train accuracy:		69.72 %
#   validation accuracy:		67.27 %
# Epoch 19 of 200 took 54.950s
#   training loss (in-iteration):		0.871004
#   train accuracy:		69.99 %
#   validation accuracy:		66.24 %
# Epoch 20 of 200 took 54.977s
#   training loss (in-iteration):		0.871652
#   train accuracy:		69.92 %
#   validation accuracy:		67.10 %
# Epoch 21 of 200 took 54.950s
#   training loss (in-iteration):		0.859638
#   train accuracy:		70.66 %
#   validation accuracy:		67.17 %
# Epoch 22 of 200 took 54.991s
#   training loss (in-iteration):		0.848359
#   train accuracy:		70.84 %
#   validation accuracy:		68.42 %
# Epoch 23 of 200 took 54.942s
#   training loss (in-iteration):		0.840231
#   train accuracy:		71.28 %
#   validation accuracy:		68.05 %
# Epoch 24 of 200 took 54.981s
#   training loss (in-iteration):		0.831863
#   train accuracy:		71.38 %
#   validation accuracy:		68.32 %
# Epoch 25 of 200 took 54.953s
#   training loss (in-iteration):		0.826724
#   train accuracy:		71.37 %
#   validation accuracy:		68.30 %
# Epoch 26 of 200 took 54.982s
#   training loss (in-iteration):		0.823983
#   train accuracy:		71.75 %
#   validation accuracy:		68.60 %
# Epoch 27 of 200 took 54.959s
#   training loss (in-iteration):		0.817363
#   train accuracy:		72.12 %
#   validation accuracy:		69.19 %
# Epoch 28 of 200 took 54.977s
#   training loss (in-iteration):		0.807244
#   train accuracy:		72.36 %
#   validation accuracy:		69.33 %
# Epoch 29 of 200 took 54.956s
#   training loss (in-iteration):		0.806999
#   train accuracy:		72.24 %
#   validation accuracy:		68.41 %
# Epoch 30 of 200 took 54.943s
#   training loss (in-iteration):		0.797224
#   train accuracy:		72.42 %
#   validation accuracy:		68.34 %
# Epoch 31 of 200 took 54.997s
#   training loss (in-iteration):		0.787126
#   train accuracy:		72.74 %
#   validation accuracy:		69.34 %
# Epoch 32 of 200 took 54.925s
#   training loss (in-iteration):		0.789914
#   train accuracy:		72.89 %
#   validation accuracy:		69.80 %
# Epoch 33 of 200 took 54.974s
#   training loss (in-iteration):		0.780753
#   train accuracy:		72.95 %
#   validation accuracy:		69.65 %
# Epoch 34 of 200 took 54.946s
#   training loss (in-iteration):		0.780684
#   train accuracy:		73.03 %
#   validation accuracy:		68.78 %
# Epoch 35 of 200 took 55.006s
#   training loss (in-iteration):		0.777443
#   train accuracy:		73.33 %
#   validation accuracy:		70.60 %
# Epoch 36 of 200 took 54.943s
#   training loss (in-iteration):		0.767035
#   train accuracy:		73.59 %
#   validation accuracy:		70.33 %
# Epoch 37 of 200 took 54.992s
#   training loss (in-iteration):		0.767293
#   train accuracy:		73.66 %
#   validation accuracy:		69.93 %
# Epoch 38 of 200 took 54.936s
#   training loss (in-iteration):		0.770119
#   train accuracy:		73.68 %
#   validation accuracy:		69.52 %
# Epoch 39 of 200 took 54.969s
#   training loss (in-iteration):		0.760542
#   train accuracy:		73.77 %
#   validation accuracy:		69.46 %
# Epoch 40 of 200 took 54.938s
#   training loss (in-iteration):		0.756294
#   train accuracy:		74.12 %
#   validation accuracy:		69.17 %
# Epoch 41 of 200 took 55.489s
#   training loss (in-iteration):		0.757964
#   train accuracy:		74.00 %
#   validation accuracy:		69.92 %
# Epoch 42 of 200 took 54.964s
#   training loss (in-iteration):		0.756310
#   train accuracy:		73.85 %
#   validation accuracy:		70.22 %
# Epoch 43 of 200 took 54.939s
#   training loss (in-iteration):		0.751993
#   train accuracy:		74.12 %
#   validation accuracy:		69.60 %
# Epoch 44 of 200 took 54.976s
#   training loss (in-iteration):		0.750093
#   train accuracy:		74.01 %
#   validation accuracy:		70.21 %
# Epoch 45 of 200 took 54.930s
#   training loss (in-iteration):		0.750664
#   train accuracy:		74.41 %
#   validation accuracy:		70.07 %
# Epoch 46 of 200 took 55.005s
#   training loss (in-iteration):		0.738412
#   train accuracy:		74.70 %
#   validation accuracy:		70.26 %
# Epoch 47 of 200 took 54.945s
#   training loss (in-iteration):		0.737792
#   train accuracy:		74.39 %
#   validation accuracy:		70.63 %
# Epoch 48 of 200 took 55.007s
#   training loss (in-iteration):		0.740176
#   train accuracy:		74.60 %
#   validation accuracy:		70.30 %
# Epoch 49 of 200 took 54.963s
#   training loss (in-iteration):		0.740987
#   train accuracy:		74.76 %
#   validation accuracy:		70.03 %
# Epoch 50 of 200 took 54.974s
#   training loss (in-iteration):		0.728638
#   train accuracy:		74.84 %
#   validation accuracy:		70.25 %
# Epoch 51 of 200 took 54.951s
#   training loss (in-iteration):		0.723665
#   train accuracy:		75.21 %
#   validation accuracy:		70.70 %
# Epoch 52 of 200 took 54.991s
#   training loss (in-iteration):		0.719750
#   train accuracy:		75.28 %
#   validation accuracy:		70.40 %
# Epoch 53 of 200 took 54.930s
#   training loss (in-iteration):		0.726223
#   train accuracy:		75.16 %
#   validation accuracy:		70.14 %
# Epoch 54 of 200 took 54.950s
#   training loss (in-iteration):		0.717210
#   train accuracy:		75.53 %
#   validation accuracy:		70.07 %
# Epoch 55 of 200 took 54.978s
#   training loss (in-iteration):		0.720680
#   train accuracy:		75.02 %
#   validation accuracy:		70.89 %
# Epoch 56 of 200 took 54.956s
#   training loss (in-iteration):		0.720441
#   train accuracy:		75.45 %
#   validation accuracy:		70.97 %
# Epoch 57 of 200 took 54.986s
#   training loss (in-iteration):		0.712751
#   train accuracy:		75.33 %
#   validation accuracy:		70.53 %
# Epoch 58 of 200 took 54.932s
#   training loss (in-iteration):		0.712325
#   train accuracy:		75.56 %
#   validation accuracy:		70.80 %
# Epoch 59 of 200 took 54.987s
#   training loss (in-iteration):		0.715400
#   train accuracy:		75.38 %
#   validation accuracy:		70.41 %
# Epoch 60 of 200 took 54.959s
#   training loss (in-iteration):		0.709008
#   train accuracy:		75.63 %
#   validation accuracy:		70.25 %
# Epoch 61 of 200 took 55.023s
#   training loss (in-iteration):		0.705232
#   train accuracy:		75.82 %
#   validation accuracy:		70.80 %
# Epoch 62 of 200 took 54.982s
#   training loss (in-iteration):		0.704699
#   train accuracy:		75.66 %
#   validation accuracy:		69.27 %
# Epoch 63 of 200 took 54.982s
#   training loss (in-iteration):		0.704708
#   train accuracy:		75.75 %
#   validation accuracy:		71.39 %
# Epoch 64 of 200 took 54.938s
#   training loss (in-iteration):		0.703880
#   train accuracy:		75.82 %
#   validation accuracy:		70.69 %
# Epoch 65 of 200 took 54.984s
#   training loss (in-iteration):		0.699942
#   train accuracy:		75.73 %
#   validation accuracy:		70.96 %
# Epoch 66 of 200 took 54.999s
#   training loss (in-iteration):		0.701326
#   train accuracy:		75.63 %
#   validation accuracy:		70.32 %
# Epoch 67 of 200 took 54.962s
#   training loss (in-iteration):		0.700008
#   train accuracy:		75.76 %
#   validation accuracy:		70.60 %
# Epoch 68 of 200 took 54.972s
#   training loss (in-iteration):		0.692983
#   train accuracy:		76.09 %
#   validation accuracy:		70.93 %
# Epoch 69 of 200 took 54.939s
#   training loss (in-iteration):		0.698221
#   train accuracy:		75.89 %
#   validation accuracy:		70.19 %
# Epoch 70 of 200 took 54.980s
#   training loss (in-iteration):		0.700305
#   train accuracy:		75.90 %
#   validation accuracy:		70.58 %
# Epoch 71 of 200 took 54.946s
#   training loss (in-iteration):		0.690234
#   train accuracy:		76.13 %
#   validation accuracy:		71.19 %
# Epoch 72 of 200 took 55.004s
#   training loss (in-iteration):		0.689827
#   train accuracy:		76.49 %
#   validation accuracy:		70.70 %
# Epoch 73 of 200 took 54.921s
#   training loss (in-iteration):		0.693082
#   train accuracy:		76.15 %
#   validation accuracy:		70.77 %
# Epoch 74 of 200 took 54.967s
#   training loss (in-iteration):		0.685557
#   train accuracy:		76.14 %
#   validation accuracy:		70.86 %
# Epoch 75 of 200 took 54.929s
#   training loss (in-iteration):		0.686107
#   train accuracy:		76.13 %
#   validation accuracy:		70.74 %
# Epoch 76 of 200 took 54.976s
#   training loss (in-iteration):		0.685212
#   train accuracy:		76.39 %
#   validation accuracy:		71.39 %
# Epoch 77 of 200 took 54.919s
#   training loss (in-iteration):		0.682939
#   train accuracy:		76.38 %
#   validation accuracy:		70.80 %
# Epoch 78 of 200 took 54.951s
#   training loss (in-iteration):		0.672840
#   train accuracy:		76.78 %
#   validation accuracy:		70.76 %
# Epoch 79 of 200 took 54.986s
#   training loss (in-iteration):		0.678993
#   train accuracy:		76.58 %
#   validation accuracy:		71.22 %
# Epoch 80 of 200 took 54.936s
#   training loss (in-iteration):		0.679040
#   train accuracy:		76.73 %
#   validation accuracy:		71.41 %
# Epoch 81 of 200 took 54.992s
#   training loss (in-iteration):		0.671321
#   train accuracy:		76.85 %
#   validation accuracy:		71.76 %
# Epoch 82 of 200 took 54.937s
#   training loss (in-iteration):		0.677738
#   train accuracy:		76.54 %
#   validation accuracy:		71.25 %
# Epoch 83 of 200 took 55.006s
#   training loss (in-iteration):		0.682436
#   train accuracy:		76.70 %
#   validation accuracy:		71.43 %
# Epoch 84 of 200 took 54.940s
#   training loss (in-iteration):		0.670782
#   train accuracy:		76.91 %
#   validation accuracy:		70.86 %
# Epoch 85 of 200 took 55.019s
#   training loss (in-iteration):		0.663941
#   train accuracy:		77.42 %
#   validation accuracy:		70.55 %
# Epoch 86 of 200 took 54.938s
#   training loss (in-iteration):		0.672127
#   train accuracy:		76.66 %
#   validation accuracy:		71.36 %
# Epoch 87 of 200 took 54.991s
#   training loss (in-iteration):		0.676656
#   train accuracy:		76.78 %
#   validation accuracy:		71.63 %
# Epoch 88 of 200 took 54.957s
#   training loss (in-iteration):		0.673005
#   train accuracy:		76.92 %
#   validation accuracy:		70.56 %
# Epoch 89 of 200 took 54.974s
#   training loss (in-iteration):		0.673564
#   train accuracy:		76.92 %
#   validation accuracy:		71.24 %
# Epoch 90 of 200 took 54.977s
#   training loss (in-iteration):		0.666095
#   train accuracy:		77.03 %
#   validation accuracy:		71.31 %
# Epoch 91 of 200 took 54.923s
#   training loss (in-iteration):		0.666616
#   train accuracy:		77.28 %
#   validation accuracy:		71.57 %
# Epoch 92 of 200 took 55.008s
#   training loss (in-iteration):		0.666140
#   train accuracy:		76.79 %
#   validation accuracy:		71.11 %
# Epoch 93 of 200 took 54.941s
#   training loss (in-iteration):		0.666574
#   train accuracy:		77.16 %
#   validation accuracy:		70.74 %
# Epoch 94 of 200 took 54.979s
#   training loss (in-iteration):		0.664518
#   train accuracy:		77.10 %
#   validation accuracy:		71.15 %
# Epoch 95 of 200 took 54.926s
#   training loss (in-iteration):		0.665456
#   train accuracy:		77.19 %
#   validation accuracy:		70.48 %
# Epoch 96 of 200 took 54.993s
#   training loss (in-iteration):		0.657932
#   train accuracy:		77.16 %
#   validation accuracy:		70.70 %
# Epoch 97 of 200 took 54.944s
#   training loss (in-iteration):		0.658217
#   train accuracy:		77.38 %
#   validation accuracy:		70.74 %
# Epoch 98 of 200 took 54.982s
#   training loss (in-iteration):		0.657736
#   train accuracy:		77.58 %
#   validation accuracy:		71.46 %
# Epoch 99 of 200 took 54.921s
#   training loss (in-iteration):		0.660161
#   train accuracy:		77.38 %
#   validation accuracy:		70.93 %
# Epoch 100 of 200 took 54.973s
#   training loss (in-iteration):		0.657699
#   train accuracy:		77.25 %
#   validation accuracy:		71.77 %
# Epoch 101 of 200 took 54.934s
#   training loss (in-iteration):		0.657677
#   train accuracy:		77.24 %
#   validation accuracy:		70.78 %
# Epoch 102 of 200 took 54.941s
#   training loss (in-iteration):		0.660273
#   train accuracy:		77.41 %
#   validation accuracy:		70.82 %
# Epoch 103 of 200 took 54.964s
#   training loss (in-iteration):		0.658553
#   train accuracy:		77.36 %
#   validation accuracy:		70.83 %
# Epoch 104 of 200 took 54.936s
#   training loss (in-iteration):		0.661763
#   train accuracy:		77.11 %
#   validation accuracy:		70.91 %
# Epoch 105 of 200 took 55.003s
#   training loss (in-iteration):		0.658671
#   train accuracy:		77.36 %
#   validation accuracy:		71.18 %
# Epoch 106 of 200 took 54.931s
#   training loss (in-iteration):		0.655005
#   train accuracy:		77.51 %
#   validation accuracy:		70.70 %
# Epoch 107 of 200 took 55.018s
#   training loss (in-iteration):		0.653713
#   train accuracy:		77.38 %
#   validation accuracy:		71.37 %
# Epoch 108 of 200 took 54.957s
#   training loss (in-iteration):		0.656135
#   train accuracy:		77.54 %
#   validation accuracy:		71.80 %
# Epoch 109 of 200 took 55.009s
#   training loss (in-iteration):		0.647715
#   train accuracy:		77.83 %
#   validation accuracy:		71.30 %
# Epoch 110 of 200 took 54.948s
#   training loss (in-iteration):		0.655253
#   train accuracy:		77.55 %
#   validation accuracy:		70.47 %
# Epoch 111 of 200 took 54.999s
#   training loss (in-iteration):		0.652777
#   train accuracy:		77.43 %
#   validation accuracy:		71.18 %
# Epoch 112 of 200 took 54.930s
#   training loss (in-iteration):		0.641065
#   train accuracy:		77.93 %
#   validation accuracy:		71.41 %
# Epoch 113 of 200 took 54.951s
#   training loss (in-iteration):		0.643568
#   train accuracy:		77.86 %
#   validation accuracy:		71.96 %
# Epoch 114 of 200 took 54.965s
#   training loss (in-iteration):		0.649083
#   train accuracy:		77.61 %
#   validation accuracy:		70.74 %
# Epoch 115 of 200 took 54.944s
#   training loss (in-iteration):		0.648237
#   train accuracy:		77.68 %
#   validation accuracy:		71.20 %
# Epoch 116 of 200 took 54.981s
#   training loss (in-iteration):		0.640685
#   train accuracy:		77.83 %
#   validation accuracy:		70.90 %
# Epoch 117 of 200 took 54.964s
#   training loss (in-iteration):		0.646604
#   train accuracy:		77.64 %
#   validation accuracy:		71.48 %
# Epoch 118 of 200 took 55.002s
#   training loss (in-iteration):		0.645351
#   train accuracy:		77.86 %
#   validation accuracy:		70.98 %
# Epoch 119 of 200 took 54.934s
#   training loss (in-iteration):		0.644911
#   train accuracy:		77.66 %
#   validation accuracy:		70.45 %
# Epoch 120 of 200 took 54.973s
#   training loss (in-iteration):		0.640516
#   train accuracy:		77.89 %
#   validation accuracy:		71.46 %
# Epoch 121 of 200 took 54.933s
#   training loss (in-iteration):		0.638104
#   train accuracy:		78.17 %
#   validation accuracy:		70.98 %
# Epoch 122 of 200 took 54.984s
#   training loss (in-iteration):		0.646402
#   train accuracy:		77.47 %
#   validation accuracy:		70.83 %
# Epoch 123 of 200 took 54.941s
#   training loss (in-iteration):		0.637421
#   train accuracy:		78.25 %
#   validation accuracy:		71.93 %
# Epoch 124 of 200 took 55.004s
#   training loss (in-iteration):		0.640526
#   train accuracy:		78.14 %
#   validation accuracy:		71.05 %
# Epoch 125 of 200 took 54.919s
#   training loss (in-iteration):		0.648063
#   train accuracy:		77.89 %
#   validation accuracy:		70.74 %
# Epoch 126 of 200 took 54.939s
#   training loss (in-iteration):		0.645957
#   train accuracy:		77.80 %
#   validation accuracy:		70.66 %
# Epoch 127 of 200 took 55.034s
#   training loss (in-iteration):		0.639196
#   train accuracy:		78.16 %
#   validation accuracy:		71.71 %
# Epoch 128 of 200 took 54.945s
#   training loss (in-iteration):		0.639273
#   train accuracy:		78.06 %
#   validation accuracy:		71.29 %
# Epoch 129 of 200 took 54.990s
#   training loss (in-iteration):		0.635631
#   train accuracy:		78.21 %
#   validation accuracy:		71.71 %
# Epoch 130 of 200 took 54.963s
#   training loss (in-iteration):		0.636787
#   train accuracy:		77.91 %
#   validation accuracy:		70.94 %
# Epoch 131 of 200 took 55.031s
#   training loss (in-iteration):		0.626938
#   train accuracy:		78.40 %
#   validation accuracy:		71.09 %
# Epoch 132 of 200 took 54.940s
#   training loss (in-iteration):		0.633205
#   train accuracy:		78.10 %
#   validation accuracy:		71.25 %
# Epoch 133 of 200 took 55.001s
#   training loss (in-iteration):		0.634237
#   train accuracy:		78.04 %
#   validation accuracy:		71.47 %
# Epoch 134 of 200 took 54.931s
#   training loss (in-iteration):		0.634199
#   train accuracy:		78.25 %
#   validation accuracy:		70.01 %
# Epoch 135 of 200 took 54.999s
#   training loss (in-iteration):		0.636324
#   train accuracy:		78.24 %
#   validation accuracy:		70.63 %
# Epoch 136 of 200 took 54.971s
#   training loss (in-iteration):		0.642380
#   train accuracy:		77.79 %
#   validation accuracy:		71.71 %
# Epoch 137 of 200 took 54.952s
#   training loss (in-iteration):		0.629468
#   train accuracy:		78.21 %
#   validation accuracy:		71.17 %
# Epoch 138 of 200 took 55.024s
#   training loss (in-iteration):		0.627139
#   train accuracy:		78.28 %
#   validation accuracy:		71.90 %
# Epoch 139 of 200 took 54.932s
#   training loss (in-iteration):		0.632176
#   train accuracy:		78.50 %
#   validation accuracy:		71.47 %
# Epoch 140 of 200 took 54.985s
#   training loss (in-iteration):		0.629075
#   train accuracy:		78.09 %
#   validation accuracy:		71.14 %
# Epoch 141 of 200 took 54.953s
#   training loss (in-iteration):		0.627013
#   train accuracy:		78.41 %
#   validation accuracy:		71.52 %
# Epoch 142 of 200 took 55.006s
#   training loss (in-iteration):		0.625113
#   train accuracy:		78.45 %
#   validation accuracy:		71.21 %
# Epoch 143 of 200 took 54.923s
#   training loss (in-iteration):		0.629964
#   train accuracy:		78.41 %
#   validation accuracy:		71.32 %
# Epoch 144 of 200 took 54.980s
#   training loss (in-iteration):		0.634836
#   train accuracy:		78.11 %
#   validation accuracy:		72.05 %
# Epoch 145 of 200 took 54.959s
#   training loss (in-iteration):		0.624488
#   train accuracy:		78.33 %
#   validation accuracy:		71.36 %
# Epoch 146 of 200 took 55.057s
#   training loss (in-iteration):		0.615781
#   train accuracy:		78.79 %
#   validation accuracy:		72.43 %
# Epoch 147 of 200 took 54.954s
#   training loss (in-iteration):		0.626896
#   train accuracy:		78.51 %
#   validation accuracy:		70.50 %
# Epoch 148 of 200 took 55.007s
#   training loss (in-iteration):		0.628538
#   train accuracy:		78.41 %
#   validation accuracy:		71.31 %
# Epoch 149 of 200 took 54.954s
#   training loss (in-iteration):		0.621701
#   train accuracy:		78.80 %
#   validation accuracy:		70.64 %
# Epoch 150 of 200 took 54.927s
#   training loss (in-iteration):		0.619974
#   train accuracy:		78.81 %
#   validation accuracy:		71.49 %
# Epoch 151 of 200 took 54.969s
#   training loss (in-iteration):		0.616635
#   train accuracy:		78.80 %
#   validation accuracy:		71.34 %
# Epoch 152 of 200 took 54.958s
#   training loss (in-iteration):		0.623420
#   train accuracy:		78.61 %
#   validation accuracy:		71.95 %
# Epoch 153 of 200 took 54.988s
#   training loss (in-iteration):		0.627431
#   train accuracy:		78.72 %
#   validation accuracy:		70.74 %
# Epoch 154 of 200 took 55.007s
#   training loss (in-iteration):		0.622269
#   train accuracy:		78.66 %
#   validation accuracy:		71.44 %
# Epoch 155 of 200 took 55.013s
#   training loss (in-iteration):		0.618128
#   train accuracy:		78.89 %
#   validation accuracy:		70.89 %
# Epoch 156 of 200 took 54.914s
#   training loss (in-iteration):		0.622426
#   train accuracy:		78.84 %
#   validation accuracy:		71.64 %
# Epoch 157 of 200 took 54.983s
#   training loss (in-iteration):		0.618258
#   train accuracy:		78.72 %
#   validation accuracy:		71.25 %
# Epoch 158 of 200 took 54.930s
#   training loss (in-iteration):		0.629543
#   train accuracy:		78.48 %
#   validation accuracy:		71.16 %
# Epoch 159 of 200 took 55.008s
#   training loss (in-iteration):		0.625344
#   train accuracy:		78.60 %
#   validation accuracy:		70.83 %
# Epoch 160 of 200 took 54.924s
#   training loss (in-iteration):		0.618172
#   train accuracy:		78.84 %
#   validation accuracy:		72.03 %
# Epoch 161 of 200 took 54.948s
#   training loss (in-iteration):		0.621240
#   train accuracy:		78.74 %
#   validation accuracy:		71.79 %
# Epoch 162 of 200 took 55.001s
#   training loss (in-iteration):		0.624866
#   train accuracy:		78.28 %
#   validation accuracy:		70.93 %
# Epoch 163 of 200 took 54.963s
#   training loss (in-iteration):		0.626525
#   train accuracy:		78.35 %
#   validation accuracy:		71.29 %
# Epoch 164 of 200 took 54.971s
#   training loss (in-iteration):		0.616935
#   train accuracy:		78.81 %
#   validation accuracy:		72.05 %
# Epoch 165 of 200 took 54.937s
#   training loss (in-iteration):		0.616974
#   train accuracy:		78.68 %
#   validation accuracy:		70.99 %
# Epoch 166 of 200 took 55.001s
#   training loss (in-iteration):		0.618474
#   train accuracy:		78.45 %
#   validation accuracy:		72.10 %
# Epoch 167 of 200 took 54.945s
#   training loss (in-iteration):		0.618692
#   train accuracy:		78.65 %
#   validation accuracy:		72.21 %
# Epoch 168 of 200 took 55.010s
#   training loss (in-iteration):		0.616527
#   train accuracy:		78.84 %
#   validation accuracy:		72.29 %
# Epoch 169 of 200 took 54.957s
#   training loss (in-iteration):		0.615187
#   train accuracy:		78.92 %
#   validation accuracy:		71.53 %
# Epoch 170 of 200 took 54.996s
#   training loss (in-iteration):		0.614579
#   train accuracy:		78.91 %
#   validation accuracy:		72.28 %
# Epoch 171 of 200 took 54.935s
#   training loss (in-iteration):		0.611706
#   train accuracy:		78.88 %
#   validation accuracy:		72.48 %
# Epoch 172 of 200 took 55.008s
#   training loss (in-iteration):		0.616322
#   train accuracy:		78.85 %
#   validation accuracy:		71.83 %
# Epoch 173 of 200 took 54.944s
#   training loss (in-iteration):		0.609206
#   train accuracy:		78.82 %
#   validation accuracy:		71.20 %
# Epoch 174 of 200 took 54.960s
#   training loss (in-iteration):		0.617335
#   train accuracy:		78.82 %
#   validation accuracy:		71.41 %
# Epoch 175 of 200 took 55.001s
#   training loss (in-iteration):		0.612923
#   train accuracy:		79.01 %
#   validation accuracy:		71.19 %
# Epoch 176 of 200 took 54.939s
#   training loss (in-iteration):		0.613920
#   train accuracy:		79.05 %
#   validation accuracy:		71.72 %
# Epoch 177 of 200 took 55.002s
#   training loss (in-iteration):		0.615340
#   train accuracy:		78.89 %
#   validation accuracy:		71.31 %
# Epoch 178 of 200 took 54.942s
#   training loss (in-iteration):		0.608918
#   train accuracy:		79.28 %
#   validation accuracy:		71.34 %
# Epoch 179 of 200 took 55.008s
#   training loss (in-iteration):		0.620801
#   train accuracy:		79.02 %
#   validation accuracy:		71.44 %
# Epoch 180 of 200 took 54.955s
#   training loss (in-iteration):		0.616883
#   train accuracy:		78.90 %
#   validation accuracy:		71.48 %
# Epoch 181 of 200 took 54.997s
#   training loss (in-iteration):		0.614670
#   train accuracy:		78.84 %
#   validation accuracy:		71.26 %
# Epoch 182 of 200 took 54.968s
#   training loss (in-iteration):		0.609329
#   train accuracy:		78.97 %
#   validation accuracy:		71.75 %
# Epoch 183 of 200 took 55.002s
#   training loss (in-iteration):		0.615704
#   train accuracy:		79.14 %
#   validation accuracy:		72.14 %
# Epoch 184 of 200 took 54.955s
#   training loss (in-iteration):		0.614004
#   train accuracy:		79.15 %
#   validation accuracy:		71.98 %
# Epoch 185 of 200 took 54.926s
#   training loss (in-iteration):		0.610710
#   train accuracy:		79.10 %
#   validation accuracy:		71.17 %
# Epoch 186 of 200 took 55.011s
#   training loss (in-iteration):		0.604897
#   train accuracy:		79.25 %
#   validation accuracy:		71.74 %
# Epoch 187 of 200 took 54.920s
#   training loss (in-iteration):		0.612345
#   train accuracy:		79.21 %
#   validation accuracy:		71.72 %
# Epoch 188 of 200 took 55.001s
#   training loss (in-iteration):		0.612000
#   train accuracy:		79.00 %
#   validation accuracy:		71.40 %
# Epoch 189 of 200 took 54.925s
#   training loss (in-iteration):		0.607330
#   train accuracy:		79.16 %
#   validation accuracy:		71.28 %
# Epoch 190 of 200 took 54.984s
#   training loss (in-iteration):		0.604884
#   train accuracy:		79.15 %
#   validation accuracy:		71.91 %
# Epoch 191 of 200 took 54.942s
#   training loss (in-iteration):		0.603792
#   train accuracy:		79.30 %
#   validation accuracy:		71.48 %
# Epoch 192 of 200 took 55.000s
#   training loss (in-iteration):		0.615948
#   train accuracy:		78.91 %
#   validation accuracy:		71.49 %
# Epoch 193 of 200 took 54.951s
#   training loss (in-iteration):		0.599604
#   train accuracy:		79.36 %
#   validation accuracy:		71.62 %
# Epoch 194 of 200 took 54.987s
#   training loss (in-iteration):		0.607886
#   train accuracy:		79.18 %
#   validation accuracy:		71.79 %
# Epoch 195 of 200 took 54.937s
#   training loss (in-iteration):		0.611257
#   train accuracy:		79.17 %
#   validation accuracy:		72.08 %
# Epoch 196 of 200 took 55.004s
#   training loss (in-iteration):		0.611436
#   train accuracy:		79.17 %
#   validation accuracy:		71.26 %
# Epoch 197 of 200 took 54.925s
#   training loss (in-iteration):		0.606953
#   train accuracy:		79.12 %
#   validation accuracy:		71.27 %
# Epoch 198 of 200 took 54.944s
#   training loss (in-iteration):		0.610562
#   train accuracy:		79.26 %
#   validation accuracy:		71.40 %
# Epoch 199 of 200 took 54.993s
#   training loss (in-iteration):		0.604914
#   train accuracy:		79.31 %
#   validation accuracy:		71.28 %
# Epoch 200 of 200 took 55.003s
#   training loss (in-iteration):		0.604446
#   train accuracy:		79.17 %
#   validation accuracy:		71.28 %

# %%
test_acc = 0
test_batches = 0
for batch in iterate_minibatches(X_test, y_test, 500):
    inputs, targets = batch
    acc = accuracy_fun(inputs, targets)
    test_acc += acc
    test_batches += 1
print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_acc / test_batches * 100))

if test_acc / test_batches * 100 > 92.5:
    print "Achievement unlocked: колдун 80 уровня"
else:
    print "Нужно больше магии!"
# Out:
# Final results:
#   test accuracy:		68.37 %
# Нужно больше магии!

# %% [markdown]
# ## Заполните форму
#
# https://goo.gl/forms/EeadABISlVmdJqgr2

# %%
import pandas as pd
import sklearn
import re
import numpy as np

# %%
train = pd.read_csv("linear_train.txt", header = None)
train.columns = ['word', 'ans']

def is_upper_case(row):
    word = str(row['word'])
    if word[0] == word[0].upper():
        return 1
    else:
        return 0

train['is_upper'] = train.apply(is_upper_case, axis=1)

train.head()
# Out:
#        word  ans  is_upper
# 0  Аалтонен    1         1
# 1       Аар    0         1
# 2     Аарон    0         1
# 3     ААРОН    0         1
# 4    Аарона    0         1

# %%
train.loc[(train['is_upper'] == 0) & (train['ans'] ==1)]
# Out:
#                  word  ans  is_upper
# 43       аббревиатура    1         0
# 446         автокаско    1         0
# 475     автоматизация    1         0
# 486         автоматов    1         0
# 658             агент    1         0
# 673         агентство    1         0
# 749     агрегирования    1         0
# 809         адаптация    1         0
# 1052             азот    1         0
# 1320              акт    1         0
# 1363        активисты    1         0
# 1391             акты    1         0
# 1523        алгоритмы    1         0
# 1638        алкоголик    1         0
# 1875            альфа    1         0
# 1987       американцы    1         0
# 2008           аминов    1         0
# 2057      амортизация    1         0
# 2085        амплитуда    1         0
# 2317         англофил    1         0
# 2729         антрацит    1         0
# 2934           апплет    1         0
# 3382          арсенал    1         0
# 3433      артиллерист    1         0
# ...

# %% [markdown]
# ## КААААК?! 1266 заведомо неверных ответов в train

# %%
good = train.loc[train['is_upper'] == 1]
lower = train.loc[train['is_upper'] == 0]
l = list(lower['word'])
lower_set = set(map(lambda x: x.lower(),l))

# %%
def check_in_lower(row):
    if row['word'] in lower_set:
        return 1
    else:
        return 0
    
train['is_in_lower'] = good.apply(check_in_lower, axis=1)

# %%
train.loc[(train['is_in_lower'] == 1) & (train['ans'] == 0) & (train['is_upper'] == 1)]
# Out:
# Empty DataFrame
# Columns: [word, ans, is_upper, is_in_lower]
# Index: []

# %%
train.loc[ (train['ans'] == 0) & (train['is_upper'] == 1)]
# Out:
#                   word  ans  is_upper  is_in_lower
# 1                  Аар    0         1          0.0
# 2                Аарон    0         1          0.0
# 3                ААРОН    0         1          0.0
# 4               Аарона    0         1          0.0
# 6               Аароне    0         1          0.0
# 7              Ааронов    0         1          0.0
# 8               Аахена    0         1          0.0
# 13             Абажуры    0         1          0.0
# 16             Абакана    0         1          0.0
# 31            Аббатиса    0         1          0.0
# 34           Аббатисой    0         1          0.0
# 39           Аббатстве    0         1          0.0
# 45              Абвилю    0         1          0.0
# 46             Абделем    0         1          0.0
# 48               Абдул    0         1          0.0
# 49              Абдуле    0         1          0.0
# 50             АБДУЛЛА    0         1          0.0
# ...

# %%
ends = set(['ко', 'ук', 'юк', 'ун', 'ний', 'ный', 'чай', 'ий', 'ин', 'ишин', 'джи', 'оглу', 'джи', 'оглу',
        'уа', 'ипа', 'заде', 'ли', 'лы', 'оглу', 'кызы', 'ян', 'янц', 'уни', 'ич', 'ук', 'ик', 'ски', 
        'ев', 'ов', 'огло', 'пулос', 'кос', 'иди', 'швили', 'дзе', 'ури', 'иа', 'уа', 'ава', 'ли', 'си', 'ни', 
        'ини', 'ис', 'ску', 'ан', 'ын', 'шкин', 'кин', 'ин', 'ман', 'ер', 'ски', 'цки',
        'дзки', 'ев', 'ов', 'ских', 'ску', 'ан', 'овая', 'ичу', 'ича', 'ен', 'ес', 'еса', 'вским', 
            'вскому', 'цевой', 'цевая'])

def is_ends(row):
    for end in ends:
        if re.match('\w+' + end +'$', row['word'].lower()):
            return 1     
    return 0

train['is_in_ends'] = good.apply(is_ends, axis=1)

# %%
train.loc[ (train['is_in_ends'] == 1) & (train['is_upper'] == 1) & (train['ans'] == 0)]
# Out:
#                   word  ans  is_upper  is_in_lower  is_in_ends
# 7              Ааронов    0         1          0.0         1.0
# 59        Абдурахманов    0         1          0.0         1.0
# 60      Абдурахманович    0         1          0.0         1.0
# 67             АБЕРДИН    0         1          0.0         1.0
# 100          Абонентов    0         1          0.0         1.0
# 119            Абортов    0         1          0.0         1.0
# 130         Абрамовича    0         1          0.0         1.0
# 148              Абрис    0         1          0.0         1.0
# 250       Авантюристов    0         1          0.0         1.0
# 298             Аветик    0         1          0.0         1.0
# 309         Авиалайнер    0         1          0.0         1.0
# 370            Аврелий    0         1          0.0         1.0
# 413          Автобусов    0         1          0.0         1.0
# 465     Автомагистрали    0         1          0.0         1.0
# ...

# %% [markdown]
# вот чем Абдурахманов, Якубович и Абдурахманович не фамилии?

# %%
train.loc[ (train['is_in_ends'] == 0) & (train['is_upper'] == 1) & (train['ans'] == 1)]
# Out:
#                word  ans  is_upper  is_in_lower  is_in_ends
# 5            Аарона    1         1          0.0         0.0
# 19         Абалкина    1         1          0.0         0.0
# 20       Абатуровым    1         1          0.0         0.0
# 23         Абашкина    1         1          0.0         0.0
# 24            Аббас    1         1          0.0         0.0
# 25            АББАС    1         1          0.0         0.0
# 26           Аббаса    1         1          0.0         0.0
# 41          Абботом    1         1          0.0         0.0
# 51      АБДУЛЛАЕВЫХ    1         1          0.0         0.0
# 54         Абдулова    1         1          0.0         0.0
# 56        Абдуловым    1         1          0.0         0.0
# 63          Абелевы    1         1          0.0         0.0
# 64          АБЕЛЕВЫ    1         1          0.0         0.0
# 65         АБЕЛЕВЫХ    1         1          0.0         0.0
# 68         Абернети    1         1          0.0         0.0
# ...

# %%
train.loc[ (train['is_in_ends'] == 1) & (train['is_upper'] == 1) & (train['ans'] == 1)]
# Out:
#                word  ans  is_upper  is_in_lower  is_in_ends
# 0          Аалтонен    1         1          0.0         1.0
# 9           Абабков    1         1          0.0         1.0
# 18         Абакумов    1         1          0.0         1.0
# 21           Абашев    1         1          0.0         1.0
# 22         Абашидзе    1         1          0.0         1.0
# 27          Аббасов    1         1          0.0         1.0
# 47       Абдрашитов    1         1          0.0         1.0
# 62           Абелев    1         1          0.0         1.0
# 134        Абрамсов    1         1          0.0         1.0
# 138      Абрамцевой    1         1          0.0         1.0
# 146       Абрикосов    1         1          0.0         1.0
# 211            Аван    1         1          0.0         1.0
# 225        Аванесов    1         1          0.0         1.0
# 272        Августин    1         1          0.0         1.0
# 278          Авдеев    1         1          0.0         1.0
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectoriser = TfidfVectorizer(ngram_range =(1,1))

# %%
full_res = np.zeros(len(train))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score

good = train.loc[train['is_upper'] == 1]

algo = LogisticRegression(penalty='l1', C=1)
ans = good.ans
data = good.drop('ans',axis=1)
matrix = vectoriser.fit_transform(good['word'], good['ans'])

algo.fit(matrix, ans)
predicted = algo.predict(matrix)
roc_auc_score(ans,predicted)
# Out:
# 0.50069355527102011

# %%
ids = list(good.index)
for i in ids:
    full_res[i] = predicted[ids.index(i)]

# %%
roc_auc_score(train['ans'],full_res)
# Out:
# 0.500611017108479

# %%
test = pd.read_csv("linear_test.txt", header = None)
test.columns = ['word']

test['is_upper'] = test.apply(is_upper_case, axis=1)
print(len(test))

full_test_res = np.zeros(len(test))
good_test = test.loc[test['is_upper'] == 1]

print(len(good_test))



matr = vectoriser.transform(good_test['word'])
preds = algo.predict(matr)
ids = list(good_test.index)
for i in ids:
    full_test_res[i] = preds[ids.index(i)]
test['ans'] =full_test_res
# Out:
# 188920
# 85352

# %%
test.to_csv("my_submission_1.tsv", sep=',', index=True)
